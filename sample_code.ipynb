# %% [markdown]
# <a href="https://colab.research.google.com/github/ParmidaRamroudi/dsclass/blob/main/sample_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = int(input("عدد اول را وارد کنید:"))
num2 = int(input("عدد دوم را وارد کنید:"))
sum_result =num1 + num2
print("مجموع دو عدد:", sum_result)
# Out:
# عدد اول را وارد کنید:33
# عدد دوم را وارد کنید:65
# مجموع دو عدد: 98
